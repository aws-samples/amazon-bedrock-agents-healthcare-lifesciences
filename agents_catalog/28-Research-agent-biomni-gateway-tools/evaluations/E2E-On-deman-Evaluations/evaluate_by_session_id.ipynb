# %% [markdown]
# # AgentCore Evaluation - Per Session
#
# Evaluate agent per session using Sessionid from AgentCore Observability

# %% [markdown]
# ## Setup

# %%
import sys

# Remove all cached utils modules
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('utils')]
for module in modules_to_remove:
    del sys.modules[module]

print("✅ Cleared cached modules")
# Out:
# ✅ Cleared cached modules

# %%
import os
from utils import EvaluationClient
import json

# AWS Credentials - Add your credentials here
os.environ['AWS_DEFAULT_REGION'] = 'us-east-1'
# os.environ['AWS_ACCESS_KEY_ID'] = ''
# os.environ['AWS_SECRET_ACCESS_KEY'] = ''
# os.environ['AWS_SESSION_TOKEN'] = ''

# %% [markdown]
# ## Configuration

# %%
# AWS Configuration
REGION = "us-east-1"
AGENT_ID = "researchappAgent-6yOZvH8hbX"
SESSION_ID = "eb81898a-9522-4a39-9b79-da51409d9b88" # pass the session id directly to evaluate 

metadata = {
        "experiment": "evaluate-session",
        "description": "Testing all evaluator scopes"
    }

# %% [markdown]
# ## Initialize Client

# %%
# Initialize evaluation client
eval_client = EvaluationClient(
    region=REGION,
)

# %% [markdown]
# ## Run Evaluations
#
# Evaluates session across all evaluator types and automatically generates dashboard.

# %%
# Evaluator Groups
FLEXIBLE_EVALUATORS = [
    "Builtin.Correctness",
    "Builtin.Faithfulness",
    "Builtin.Helpfulness",
    "Builtin.ResponseRelevance",
    "Builtin.Conciseness",
    "Builtin.Coherence",
    "Builtin.InstructionFollowing",
    "Builtin.Refusal",
    "Builtin.Harmfulness",
    "Builtin.Stereotyping"
]

SESSION_ONLY_EVALUATORS = ["Builtin.GoalSuccessRate"]

SPAN_ONLY_EVALUATORS = [
    "Builtin.ToolSelectionAccuracy",
    "Builtin.ToolParameterAccuracy"
]

# %%
test_groups = [
    {
        "name": "Flexible Evaluators (session scope)",
        "evaluators": FLEXIBLE_EVALUATORS,
        "scope": "session"
    },
    {
        "name": "Session-Only Evaluators",
        "evaluators": SESSION_ONLY_EVALUATORS,
        "scope": "session"
    },
    {
        "name": "Span-Only Evaluators",
        "evaluators": SPAN_ONLY_EVALUATORS,
        "scope": "span"
    }
]

all_results = []

for group in test_groups:
    try:
        results = eval_client.evaluate_session(
            session_id=SESSION_ID,
            evaluator_ids=group['evaluators'],
            agent_id=AGENT_ID,
            region=REGION,
            scope=group['scope'],
            auto_save_input=True, 
            auto_save_output=True,
            auto_create_dashboard=True,
            metadata=metadata
        )
        
        print(f"\nCompleted: {len(results.results)} evaluations")
        for r in results.results:
            print(f"  {r.evaluator_name}: {r.value} - {r.label}")
            all_results.append(r)
            
    except Exception as e:
        print(f"\nError: {e}")
# Out:
# 2026-02-13 12:55:18,594 - cloudwatch_client - INFO - Fetching session data for: eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:55:18,594 - cloudwatch_client - INFO - Querying spans for session: eb81898a-9522-4a39-9b79-da51409d9b88 (agent: researchappAgent-6yOZvH8hbX)
# 2026-02-13 12:55:21,998 - cloudwatch_client - INFO - Found 168 spans for session eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:55:21,999 - cloudwatch_client - INFO - Querying runtime logs for 1 traces
# 2026-02-13 12:55:27,389 - cloudwatch_client - INFO - Found 562 runtime logs across 1 traces
# 2026-02-13 12:55:27,389 - cloudwatch_client - INFO - Session data retrieved: 168 spans, 1 traces, 562 runtime logs
# Found 168 spans across 1 traces in session
# Collecting most recent 1000 relevant items
# ✅ Timestamp normalization applied: 463 log events normalized
# Sending 610 items (610 spans [582 with gen_ai attrs], 463 log events) to evaluation API
# Input saved to: evaluation_input/input_eb81898a-9522-4a_20260213_125527.json
# Output saved to: evaluation_output/output_eb81898a-9522-4a_20260213_125639.json
# Found 1 evaluation output file(s)
# Found 1 input file(s) with trace data
# Dashboard data generated: 1 session(s), 10 evaluation(s)
# 2026-02-13 12:56:40,111 - cloudwatch_client - INFO - Fetching session data for: eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:56:40,111 - cloudwatch_client - INFO - Querying spans for session: eb81898a-9522-4a39-9b79-da51409d9b88 (agent: researchappAgent-6yOZvH8hbX)
# Opening dashboard in browser: evaluation_dashboard.html
#
# Completed: 10 evaluations
#   Builtin.Correctness:  -
#   Builtin.Faithfulness:  -
#   Builtin.Helpfulness:  -
#   Builtin.ResponseRelevance:  -
#   Builtin.Conciseness:  -
#   Builtin.Coherence:  -
#   Builtin.InstructionFollowing:  -
#   Builtin.Refusal:  -
#   Builtin.Harmfulness:  -
#   Builtin.Stereotyping:  -
# 2026-02-13 12:56:43,554 - cloudwatch_client - INFO - Found 168 spans for session eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:56:43,555 - cloudwatch_client - INFO - Querying runtime logs for 1 traces
# 2026-02-13 12:56:52,109 - cloudwatch_client - INFO - Found 562 runtime logs across 1 traces
# 2026-02-13 12:56:52,110 - cloudwatch_client - INFO - Session data retrieved: 168 spans, 1 traces, 562 runtime logs
# Found 168 spans across 1 traces in session
# Collecting most recent 1000 relevant items
# ✅ Timestamp normalization applied: 463 log events normalized
# Sending 610 items (610 spans [582 with gen_ai attrs], 463 log events) to evaluation API
# Input saved to: evaluation_input/input_eb81898a-9522-4a_20260213_125652.json
# Output saved to: evaluation_output/output_eb81898a-9522-4a_20260213_125659.json
# Found 2 evaluation output file(s)
# Found 2 input file(s) with trace data
# Dashboard data generated: 1 session(s), 11 evaluation(s)
# 2026-02-13 12:57:00,303 - cloudwatch_client - INFO - Fetching session data for: eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:57:00,304 - cloudwatch_client - INFO - Querying spans for session: eb81898a-9522-4a39-9b79-da51409d9b88 (agent: researchappAgent-6yOZvH8hbX)
# Opening dashboard in browser: evaluation_dashboard.html
#
# Completed: 1 evaluations
#   Builtin.GoalSuccessRate:  -
# 2026-02-13 12:57:03,668 - cloudwatch_client - INFO - Found 168 spans for session eb81898a-9522-4a39-9b79-da51409d9b88
# 2026-02-13 12:57:03,670 - cloudwatch_client - INFO - Querying runtime logs for 1 traces
# 2026-02-13 12:57:11,628 - cloudwatch_client - INFO - Found 562 runtime logs across 1 traces
# 2026-02-13 12:57:11,628 - cloudwatch_client - INFO - Session data retrieved: 168 spans, 1 traces, 562 runtime logs
# Found 168 spans across 1 traces in session
# Warning: Found 11 tool execution spans, limiting to 10 most recent (API limit)
# Found 10 tool execution spans for evaluation
# Evaluation target: spanIds = ['f3b8efc55627e2be', '16075ef0cac6aaf2', '9c4a23b6a8ce1817', '9d3aaa7aa764e18b', 'b414929b52b6c449', 'a65725c70dcec438', 'ac81b4b143817020', '83b08d77d52520c6', '4f49e1e5c7c76551', '0756baf3dc6631f4']
# Collecting most recent 1000 relevant items
# ✅ Timestamp normalization applied: 463 log events normalized
# Sending 610 items (610 spans [582 with gen_ai attrs], 463 log events) to evaluation API
# Input saved to: evaluation_input/input_eb81898a-9522-4a_20260213_125711.json
# Output saved to: evaluation_output/output_eb81898a-9522-4a_20260213_125726.json
# Found 3 evaluation output file(s)
# Found 3 input file(s) with trace data
# Dashboard data generated: 1 session(s), 31 evaluation(s)
# Opening dashboard in browser: evaluation_dashboard.html
#
# Completed: 20 evaluations
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolSelectionAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -
#   Builtin.ToolParameterAccuracy:  -

# %% [markdown]
# # End
